# %%
# Imports 
import pandas as pd
import sqlalchemy

# %%
# Create SQLAlchemy engine for connecting to SQLite database
engine = sqlalchemy.create_engine("sqlite:///test.db?journal_mode=DELETE&synchronous=NORMAL&temp_store=MEMORY")

# %%
# Data Path
path = 'Data/POS_Data.xlsx'

# Retrieve Data
raw_data = pd.read_excel(path, sheet_name='POS')

raw_data.head()
# Out:
#    Check ID                    Item Name  Gross Revenue       Date  \
# 0      5723  BVC - WATER SMARTWATER 20OZ           1.59 2020-11-20
# 1     27172  BVC - WATER SMARTWATER 20OZ           0.00 2020-10-28
# 2     34799  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-28
# 3     64634  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-27
# 4     64634  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-27
#
#   Sale Time - Exact          Category     Day Part Is Beverage on Check  \
# 0          21:22:30  ADD>BreakfstAdds   Late Night                  Yes
# 1          12:47:50  ADD>BreakfstAdds        Lunch                  Yes
# 2          07:15:04  ADD>BreakfstAdds    Breakfast                  Yes
# 3          08:39:39  ADD>BreakfstAdds    Breakfast                  Yes
# 4          08:39:39  ADD>BreakfstAdds  Mid Morning                  Yes
#
#   Cost Center
# 0  Hospital B
# 1  Hospital A
# 2  Hospital A
# 3  Hospital A
# 4  Hospital A

# %%
# Clean Column Names
raw_data.columns = (
    raw_data.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('-', '_')
    .str.replace('___', '_')
    .str.replace('__', '_')
    .str.replace('-', '_')
    .str.replace(r'[^a-z0-9_]', '', regex=True)
)

raw_data.head()
# Out:
#    check_id                    item_name  gross_revenue       date  \
# 0      5723  BVC - WATER SMARTWATER 20OZ           1.59 2020-11-20
# 1     27172  BVC - WATER SMARTWATER 20OZ           0.00 2020-10-28
# 2     34799  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-28
# 3     64634  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-27
# 4     64634  BVC - WATER SMARTWATER 20OZ           1.59 2020-10-27
#
#   sale_time_exact          category     day_part is_beverage_on_check  \
# 0        21:22:30  ADD>BreakfstAdds   Late Night                  Yes
# 1        12:47:50  ADD>BreakfstAdds        Lunch                  Yes
# 2        07:15:04  ADD>BreakfstAdds    Breakfast                  Yes
# 3        08:39:39  ADD>BreakfstAdds    Breakfast                  Yes
# 4        08:39:39  ADD>BreakfstAdds  Mid Morning                  Yes
#
#   cost_center
# 0  Hospital B
# 1  Hospital A
# 2  Hospital A
# 3  Hospital A
# 4  Hospital A

# %%
raw_data['group'] = raw_data['item_name'].str.split(' - ', n=1).str[0]
raw_data['item_name'] = raw_data['item_name'].str.split(' - ', n=1).str[-1]
raw_data['sub_category'] = raw_data['category'].str.split('>').str[-1]
raw_data['category'] = raw_data['category'].str.split('>').str[0]

line_items = raw_data.assign(
    timestamp=lambda df: pd.to_datetime(raw_data['date'].astype(str) + ' ' + raw_data['sale_time_exact'].astype(str), format='%Y-%m-%d %H:%M:%S', errors='coerce'),
)

# Drop unneeded date/time columns
line_items = line_items.drop(columns=['date', 'sale_time_exact'])

line_items.head()
# Out:
#    check_id              item_name  gross_revenue category     day_part  \
# 0      5723  WATER SMARTWATER 20OZ           1.59      ADD   Late Night
# 1     27172  WATER SMARTWATER 20OZ           0.00      ADD        Lunch
# 2     34799  WATER SMARTWATER 20OZ           1.59      ADD    Breakfast
# 3     64634  WATER SMARTWATER 20OZ           1.59      ADD    Breakfast
# 4     64634  WATER SMARTWATER 20OZ           1.59      ADD  Mid Morning
#
#   is_beverage_on_check cost_center group  sub_category           timestamp
# 0                  Yes  Hospital B   BVC  BreakfstAdds 2020-11-20 21:22:30
# 1                  Yes  Hospital A   BVC  BreakfstAdds 2020-10-28 12:47:50
# 2                  Yes  Hospital A   BVC  BreakfstAdds 2020-10-28 07:15:04
# 3                  Yes  Hospital A   BVC  BreakfstAdds 2020-10-27 08:39:39
# 4                  Yes  Hospital A   BVC  BreakfstAdds 2020-10-27 08:39:39

# %%
line_items['is_beverage_on_check'] = line_items['is_beverage_on_check'].str.lower().str.strip() == 'yes'

line_items = line_items.astype({
    'check_id': 'string',
    'item_name': 'string',
    'gross_revenue': 'float',
    'category': 'string',
    'sub_category': 'string',
    'day_part': 'string',
    'is_beverage_on_check': 'boolean',
    'cost_center': 'string',
    'group': 'string',
    'timestamp': 'datetime64[ns]'
})


# Add the primary key column (1-based index)
line_items['line_item_id'] = line_items.index + 1


# Load line items to SQLite database
line_items.to_sql("line_items", engine, if_exists="replace", index=True, chunksize=8192, method="multi")


line_items.head()
# Out:
#   check_id              item_name  gross_revenue category     day_part  \
# 0     5723  WATER SMARTWATER 20OZ           1.59      ADD   Late Night
# 1    27172  WATER SMARTWATER 20OZ           0.00      ADD        Lunch
# 2    34799  WATER SMARTWATER 20OZ           1.59      ADD    Breakfast
# 3    64634  WATER SMARTWATER 20OZ           1.59      ADD    Breakfast
# 4    64634  WATER SMARTWATER 20OZ           1.59      ADD  Mid Morning
#
#    is_beverage_on_check cost_center group  sub_category           timestamp  \
# 0                  True  Hospital B   BVC  BreakfstAdds 2020-11-20 21:22:30
# 1                  True  Hospital A   BVC  BreakfstAdds 2020-10-28 12:47:50
# 2                  True  Hospital A   BVC  BreakfstAdds 2020-10-28 07:15:04
# 3                  True  Hospital A   BVC  BreakfstAdds 2020-10-27 08:39:39
# 4                  True  Hospital A   BVC  BreakfstAdds 2020-10-27 08:39:39
#
#    line_item_id
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5

# %%
# build transactions table and enforce data types
transactions = line_items.groupby(['check_id']).agg(
    timestamp = ('timestamp', 'first'),
    total_amount=('gross_revenue', 'sum'),
    num_items=('item_name', 'count'),
    cost_center=('cost_center', 'first'),
    day_part=('day_part', 'first'),
    top_group = ('group', lambda x: x.mode()[0]),
    is_beverage_on_check = ('is_beverage_on_check', 'first')
    ).reset_index().astype({
        'check_id': 'string',
        'timestamp': 'datetime64[ns]',
        'total_amount': 'float64',
        'num_items': 'Int64',
        'cost_center': 'string',
        'day_part': 'string',
        'top_group': 'string',
    })

# # Add the primary key column (1-based index)
# transactions['transactions_id'] = transactions.index + 1

# Load transactions table to SQLite database
transactions.to_sql("transactions", engine, if_exists="replace", index=True, chunksize=8192, method="multi")

transactions.head()
# Out:
#    check_id           timestamp  total_amount  num_items cost_center day_part  \
# 0  10000003 2020-10-23 11:58:15          4.09          1  Hospital A    Lunch
# 1  10000360 2020-10-23 13:05:04          9.66          4  Hospital B    Lunch
# 2  10000365 2020-10-23 12:33:39          5.49          1  Hospital B    Lunch
# 3  10000385 2020-10-23 12:41:35         12.46          5  Hospital A    Lunch
# 4  10000390 2020-10-23 13:15:30          0.99          1  Hospital A    Lunch
#
#          top_group  is_beverage_on_check
# 0              GRL                 False
# 1              GRL                  True
# 2  TUKEY PROVOLONE                 False
# 3              GRL                  True
# 4              BFK                 False

# %%
# Build items table
items = line_items[['item_name', 'group', 'category', 'sub_category', 'gross_revenue', 'cost_center']].drop_duplicates().sort_values('item_name').reset_index(drop=True)
items = items.astype({
    'item_name': 'string',
    'group': 'string',
    'category': 'string',
    'sub_category': 'string',
    'gross_revenue': 'float64',
    'cost_center': 'string'
}) 

items = items.rename(columns={'gross_revenue': 'price'})

# Load items table to SQLite database
items.to_sql("items", engine, if_exists="replace", index=True, chunksize=8192, method="multi")

items.head()
# Out:
#                item_name group category sub_category  price cost_center
# 0   CAFE KITCHEN CHICKEN   ENT   Entree       Entree   6.99  Hospital A
# 1   CAFE KITCHEN CHICKEN   ENT   Entree       Entree   0.00  Hospital A
# 2     CAFE KITCHEN PASTA   ENT   Entree       Entree   5.99  Hospital A
# 3     CAFE KITCHEN PASTA   ENT   Entree       Entree   0.00  Hospital A
# 4        GUEST TRAY 7.50   ENT   Entree       Entree  13.86  Hospital A

# %%
#Build categories table
categories = line_items[['category', 'sub_category', 'cost_center']].drop_duplicates().sort_values(['category', 'sub_category', 'cost_center']).reset_index(drop=True)

with pd.option_context('display.max_rows', None,
                    'display.max_columns', None,
                    'display.width', None,
                    'display.max_colwidth', None):
    display(categories)


# Load categories table into SQLite database
categories.to_sql("categories", engine, if_exists="replace", index=True, chunksize=8192, method="multi")
# Out:
#              category      sub_category cost_center
# 0                 ADD      BreakfstAdds  Hospital A
# 1                 ADD      BreakfstAdds  Hospital B
# 2                 ADD       Coffee Adds  Hospital A
# 3                 ADD       Coffee Adds  Hospital B
# 4                 ADD        Combo Adds  Hospital A
# 5                 ADD        Combo Adds  Hospital B
# 6                 ADD        Pizza Adds  Hospital A
# 7                 ADD        Pizza Adds  Hospital B
# 8                 ADD         Sand Adds  Hospital A
# 9                 ALC              Beer  Hospital A
# 10                ALC              Beer  Hospital B
# 11                ALC            Liquor  Hospital A
# 12                ALC            Liquor  Hospital B
# 13                Add      BreakfstAdds  Hospital A
# 14                BAK           Brownie  Hospital A
# 15                BAK           Brownie  Hospital B
# 16                BEV      ProteinDrink  Hospital A
# 17                BFK      Bfk Potatoes  Hospital B
# 18                BFK         Egg Other  Hospital A
# 19                BFK      French Toast  Hospital A
# 20     Bakery/Dessert    Bakery/Dessert  Hospital A
# 21     Bakery/Dessert    Bakery/Dessert  Hospital B
# 22          Beverage              Water  Hospital B
# 23        Beverage Co       Beverage Co  Hospital A
# 24        Beverage Co       Beverage Co  Hospital B
# 25      Beverage Cold     Beverage Cold  Hospital A
# 26      Beverage Cold     Beverage Cold  Hospital B
# 27       Beverage Hot      Beverage Hot  Hospital A
# 28       Beverage Hot      Beverage Hot  Hospital B
# 29   Bottled Beverage  Bottled Beverage  Hospital B
# 30          Breakfast         Breakfast  Hospital A
# 31          Breakfast         Breakfast  Hospital B
# 32         Bulk Snack        Bulk Snack  Hospital A
# 33                CON          Dressing  Hospital A
# 34                CON          Dressing  Hospital B
# 35           Catering          Catering  Hospital A
# 36           Catering          Catering  Hospital B
# 37              Chips             Chips  Hospital A
# 38      Cold Beverage     Cold Beverage  Hospital B
# 39     Cold Beverages    Cold Beverages  Hospital B
# 40               Deli              Deli  Hospital A
# 41               Deli              Deli  Hospital B
# 42            Dessert           Dessert  Hospital A
# 43                ENT         ENT Other  Hospital A
# 44                ENT      Sandwich Hot  Hospital A
# 45               EVOO              EVOO  Hospital A
# 46             Entree            Entree  Hospital A
# 47             Entree            Entree  Hospital B
# 48            Entrees           Entrees  Hospital A
# 49            Entrees           Entrees  Hospital B
# 50             Entrée            Entrée  Hospital A
# 51             Entrée            Entrée  Hospital B
# 52         Exhibition        Exhibition  Hospital A
# 53         Exhibition        Exhibition  Hospital B
# 54        FIRST COAST       FIRST COAST  Hospital A
# 55        FIRST COAST       FIRST COAST  Hospital B
# 56          GRAB & GO         GRAB & GO  Hospital A
# 57              GRILL             GRILL  Hospital A
# 58              GRILL             GRILL  Hospital B
# 59          Grab & Go         Grab & Go  Hospital A
# 60          Grab N Go         Grab N Go  Hospital A
# 61          Grab N Go         Grab N Go  Hospital B
# 62              Grill             Grill  Hospital A
# 63              Grill             Grill  Hospital B
# 64                IMP             Chips  Hospital A
# 65                IMP      Mix Fr/Nt/Cn  Hospital A
# 66            Impulse           Impulse  Hospital A
# 67            Impulse           Impulse  Hospital B
# 68      Impulse/Snack     Impulse/Snack  Hospital A
# 69      Impulse/Snack     Impulse/Snack  Hospital B
# 70     Impulse/Snacks    Impulse/Snacks  Hospital A
# 71      Lunch Entrees     Lunch Entrees  Hospital B
# 72        Lunch Sides       Lunch Sides  Hospital A
# 73      MMarket Snack     MMarket Snack  Hospital A
# 74      MMarket Snack     MMarket Snack  Hospital B
# 75        Main Entree       Main Entree  Hospital A
# 76        Main Entree       Main Entree  Hospital B
# 77               Misc              Misc  Hospital A
# 78              Misc.             Misc.  Hospital B
# 79          On the Go         On the Go  Hospital A
# 80           Outtakes          Outtakes  Hospital A
# 81           Outtakes          Outtakes  Hospital B
# 82        Park Action       Park Action  Hospital A
# 83              Pizza             Pizza  Hospital A
# 84              Promo             Promo  Hospital B
# 85             Retail            Retail  Hospital A
# 86             Retail            Retail  Hospital B
# 87                SID          Potatoes  Hospital B
# 88          Salad Bar         Salad Bar  Hospital A
# 89          Salad Bar         Salad Bar  Hospital B
# 90             Salads            Salads  Hospital A
# 91         Sandwiches        Sandwiches  Hospital A
# 92         Sandwiches        Sandwiches  Hospital B
# 93              Sides             Sides  Hospital A
# 94              Sides             Sides  Hospital B
# 95         Soup/Chili        Soup/Chili  Hospital A
# 96         Soup/Chili        Soup/Chili  Hospital B
# 97        Soup/Salads       Soup/Salads  Hospital A
# 98           Sushi DO          Sushi DO  Hospital B
# 99          Trattoria         Trattoria  Hospital A
# 100         Trattoria         Trattoria  Hospital B
# 101          Wellness          Wellness  Hospital A
# 102        zBeverage              Water  Hospital B
# 103

# %%
# Basket Combo Pipeline Testing

import pandas as pd
from collections import Counter, defaultdict
import itertools
import sqlalchemy

# Create SQLAlchemy engine
engine = sqlalchemy.create_engine("sqlite:///C1_case_study.db")

fact_line_items = pd.read_sql_table('fact_line_items', engine)
dim_items = pd.read_sql_table('dim_items', engine)


# Join Fact Line Items on Dim Items (to get Name)
line_items_named = fact_line_items.merge(dim_items, on='item_id')

# Group items by Transaction ID to get baskets
baskets = line_items_named.groupby('transaction_id')['item_name'].apply(list)

# Filter for Multi-Item Baskets
multi_item_baskets = baskets[baskets.apply(len) > 1]

# Identify multi-item transaction IDs
multi_tx_ids = multi_item_baskets.index

# Filter line items to only multi-item transactions
multi_line_items = line_items_named[line_items_named['transaction_id'].isin(multi_tx_ids)]

# Find All Pairs with Frequency and Total Revenue
pair_counts = Counter()
pair_revenue = defaultdict(float)
for tx_id in multi_tx_ids:
    tx_lines = multi_line_items[multi_line_items['transaction_id'] == tx_id]
    item_rev = tx_lines.groupby('item_name')['gross_revenue'].sum().to_dict()
    unique_items = sorted(item_rev.keys())
    if len(unique_items) > 1:
        pairs = list(itertools.combinations(unique_items, 2))
        pair_counts.update(pairs)
        for pair in pairs:
            a, b = pair
            pair_revenue[pair] += item_rev.get(a, 0) + item_rev.get(b, 0)

# Create dataframe for pairs
pairs_data = []
for pair, freq in sorted(pair_counts.items(), key=lambda x: pair_revenue[x[0]], reverse=True):
    revenue = pair_revenue[pair]
    if revenue > 0 and freq > 0:
        pairs_data.append({'Pair': pair, 'Frequency': freq, 'Total Revenue': revenue})

all_pairs = pd.DataFrame(pairs_data).sort_values(['Frequency'], ascending=False).reset_index(drop=True)

# To prevent display truncation if there are many rows
pd.set_option('display.max_rows', None)

print("All Combinations with Frequency > 0 and Total Revenue > 0:")
all_pairs.head()
# Out:
# All Combinations with Frequency > 0 and Total Revenue > 0:
#                                   Pair  Frequency  Total Revenue
# 0             (ENTREE 4.29, SIDE 1.29)       3659   21212.819696
# 1               (BACON 3 SLICES, EGGS)       2348    8250.039975
# 2  (ENT -PREMIUM SIDE 1.39, SIDE 1.29)       2195    6195.719878
# 3             (ENTREE 4.79, SIDE 1.29)       2171   14391.029803
# 4                   (EGGS, HOME FRIES)       1961    7442.499915

# %%
import pandas as pd
from collections import Counter, defaultdict
import itertools

# Assuming fact_line_items and dim_items are defined elsewhere, and fact_line_items has 'gross_revenue',
# and dim_items has 'item_cost_center' and 'item_name' (assuming item_name is unique)

# Basket/combo analysis

# Join Fact Line Items on Dim Items (to get Name and other fields)
line_items_named = fact_line_items.merge(dim_items, on='item_id')

# Group items by Transaction ID to get baskets
baskets = line_items_named.groupby('transaction_id')['item_name'].apply(list)

# Filter for Multi-Item Baskets
multi_item_baskets = baskets[baskets.apply(len) > 1]

# Identify multi-item transaction IDs
multi_tx_ids = multi_item_baskets.index

# Filter line items to only multi-item transactions
multi_line_items = line_items_named[line_items_named['transaction_id'].isin(multi_tx_ids)]

# Get item to cost center mapping (assuming unique item_name)
item_to_cc = dim_items.set_index('item_name')['item_cost_center'].to_dict()

# Find All Pairs with Frequency and Total Revenue, only if same cost center
pair_counts = Counter()
pair_revenue = defaultdict(float)
for tx_id in multi_tx_ids:
    tx_lines = multi_line_items[multi_line_items['transaction_id'] == tx_id]
    item_rev = tx_lines.groupby('item_name')['gross_revenue'].sum().to_dict()
    unique_items = sorted(item_rev.keys())
    if len(unique_items) > 1:
        for pair in itertools.combinations(unique_items, 2):
            a, b = pair
            cc1 = item_to_cc.get(a)
            cc2 = item_to_cc.get(b)
            if cc1 == cc2 and cc1 is not None:
                pair_counts[pair] += 1
                pair_revenue[pair] += item_rev.get(a, 0) + item_rev.get(b, 0)

# Create dataframe for pairs
pairs_data = []
for pair, freq in sorted(pair_counts.items(), key=lambda x: pair_revenue[x[0]], reverse=True):
    revenue = pair_revenue[pair]
    if revenue > 0 and freq > 0:
        a, b = pair
        cc = item_to_cc.get(a)  # Since same as b
        pairs_data.append({
            'Cost Center': cc,
            'Item1': a,
            'Item2': b,
            'Frequency': freq,
            'Total Revenue': revenue
        })

all_pairs = pd.DataFrame(pairs_data)

# To prevent display truncation if there are many rows
pd.set_option('display.max_rows', None)

print("All Combinations with Frequency > 0 and Total Revenue > 0 (same cost center only):")
print(all_pairs)

# Save to CSV for import into PowerBI
all_pairs.to_csv('all_pairs_with_cost_center.csv', index=False)

# Find All Singles in Multi-Item Baskets with Frequency and Total Revenue
single_counts = Counter()
single_revenue = defaultdict(float)
for tx_id in multi_tx_ids:
    tx_lines = multi_line_items[multi_line_items['transaction_id'] == tx_id]
    item_rev = tx_lines.groupby('item_name')['gross_revenue'].sum().to_dict()
    unique_items = set(item_rev.keys())
    for item in unique_items:
        single_counts[item] += 1
        single_revenue[item] += item_rev.get(item, 0)

# Create dataframe for singles
singles_data = []
for item, freq in sorted(single_counts.items(), key=lambda x: single_revenue[x[0]], reverse=True):
    revenue = single_revenue[item]
    if revenue > 0 and freq > 0:
        cc = item_to_cc.get(item)
        singles_data.append({
            'Item': item,
            'Cost Center': cc,
            'Frequency': freq,
            'Total Revenue': revenue
        })

all_singles_in_multi = pd.DataFrame(singles_data)

print("\nAll Single Items in Multi-Item Baskets with Frequency > 0 and Total Revenue > 0:")
print(all_singles_in_multi)

# Save to CSV for import into PowerBI
all_singles_in_multi.to_csv('all_singles_with_cost_center.csv', index=False)
# Out:
# All Combinations with Frequency > 0 and Total Revenue > 0 (same cost center only):
#       Cost Center                                         Item1  \
# 0      Hospital B                                   ENTREE 4.29
# 1      Hospital B                                   ENTREE 4.79
# 2      Hospital B                                   ENTREE 4.99
# 3      Hospital B                                 BURGER CHEESE
# 4      Hospital B                                   ENTREE 4.99
# 5      Hospital B                                BACON 3 SLICES
# 6      Hospital B                                 SALMON ENTRÉE
# 7      Hospital B                                          EGGS
# 8      Hospital B                                          EGGS
# 9      Hospital B                        ENT -PREMIUM SIDE 1.39
# 10     Hospital B                        ENT -PREMIUM SIDE 1.39
# 11     Hospital B                        ENT -PREMIUM SIDE 1.39
# 12     Hospital B                                        BURGER
# 13     Hospital B                                   ENTREE 4.79
# 14     Hospital B                                 BURGER CHEESE
# 15     Hospital A                             ADD A BEVERAGE $1
# 16     Hospital B                                BACON 3 SLICES
# 17     Hospital B                                     SIDE 1.29
# 18     Hospital A                             ADD A BEVERAGE $1
# 19     Hospital B                                    HOME FRIES
# 20     Hospital B                               BISCUIT W/GRAVY
# 21     Hospital B                        ENT -PREMIUM SIDE 1.39
# 22     Hospital B                                 BURGER CHEESE
# 23     Hospital B                                       BISCUIT
# 24     Hospital B                             CHICKEN TENDERS 3
# 25     Hospital B                                       BISCUIT
# 26     Hospital A                             ADD A BEVERAGE $1
# 27     Hospital B                                         FRIES
# 28     Hospital B                               BISCUIT W/GRAVY
# 29     Hospital B                                BACON 3 SLICES
# 30     Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 31     Hospital B                                BREAKFAST TACO
# 32     Hospital B                                BACON 3 SLICES
# 33     Hospital B                               MIX IT UP SALAD
# 34     Hospital B                                 SALMON ENTRÉE
# 35     Hospital B                                          EGGS
# 36     Hospital B                               MIX IT UP SALAD
# 37     Hospital B                            BAKED SWEET POTATO
# 38     Hospital A                             ADD A BEVERAGE $1
# 39     Hospital B                        ENT -PREMIUM SIDE 1.39
# 40     Hospital B                                   COFFEE 12OZ
# 41     Hospital B                                BACON 3 SLICES
# 42     Hospital B                                GRILL TOPPINGS
# 43     Hospital B                                        BURGER
# 44     Hospital B                                    HOME FRIES
# 45     Hospital B                                BREAKFAST TACO
# 46     Hospital B                            BAKED SWEET POTATO
# 47     Hospital B                                   ENTREE 4.29
# 48     Hospital B                                         FRIES
# 49     Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 50     Hospital B                                   COFFEE 16OZ
# 51     Hospital B                                 BURGER CHEESE
# 52     Hospital A                                    FRUIT CUPS
# 53     Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 54     Hospital B                                BACON 3 SLICES
# 55     Hospital B                                     SIDE 1.29
# 56     Hospital B                                 BACON 1 SLICE
# 57     Hospital B                                         FRIES
# 58     Hospital A                             ADD A BEVERAGE $1
# 59     Hospital B                               BISCUIT W/GRAVY
# 60     Hospital B                        ENT -PREMIUM SIDE 1.39
# 61     Hospital B                                          EGGS
# 62     Hospital B                                         FRIES
# 63     Hospital B                                BACON 3 SLICES
# 64     Hospital B                                     SIDE 1.29
# 65     Hospital B                               MIX IT UP SALAD
# 66     Hospital B                                   ENTREE 4.29
# 67     Hospital B                                     SIDE 1.29
# 68     Hospital B                                   CARVED-DELI
# 69     Hospital B                                       BISCUIT
# 70     Hospital B                                   COFFEE 12OZ
# 71     Hospital B                                 BURGER CHEESE
# 72     Hospital B                                BACON 3 SLICES
# 73     Hospital B                                   CARVED-DELI
# 74     Hospital B                                     SIDE 1.29
# 75     Hospital B                                          EGGS
# 76     Hospital A                             ADD A BEVERAGE $1
# 77     Hospital A                                    FRUIT CUPS
# 78     Hospital A                                BOILED EGG CUP
# 79     Hospital B                            BAKED SWEET POTATO
# 80     Hospital A                                    2 FOR 2.49
# 81     Hospital A                             ADD A BEVERAGE $1
# 82     Hospital B                                   ENTREE 4.29
# 83     Hospital B                                   ENTREE 4.29
# 84     Hospital B                                   COFFEE 12OZ
# 85     Hospital A                             ADD A BEVERAGE $1
# 86     Hospital B                               MIX IT UP SALAD
# 87     Hospital B                                BACON 3 SLICES
# 88     Hospital B                                   ENTREE 4.79
# 89     Hospital B                                   ENTREE 4.79
# 90     Hospital B                                   COFFEE 12OZ
# 91     Hospital B                                 REFRIED BEANS
# 92     Hospital A                                 BEYOND BURGER
# 93     Hospital B                            FRIES SWEET POTATO
# 94     Hospital B                                BACON 3 SLICES
# 95     Hospital B                                   ONION RINGS
# 96     Hospital B                                   ENTREE 4.29
# 97     Hospital B                                   COFFEE 16OZ
# 98     Hospital B                                   HASH BROWNS
# 99     Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 100    Hospital B                             DASANI WATER 20OZ
# 101    Hospital A                             ADD A BEVERAGE $1
# 102    Hospital B                                BACON 3 SLICES
# 103    Hospital B                                   ENTREE 5.99
# 104    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 105    Hospital B                                   CARVED-DELI
# 106    Hospital A                            BREAKFAST SANDWICH
# 107    Hospital B                               MIX IT UP SALAD
# 108    Hospital B                                   COFFEE 16OZ
# 109    Hospital B                                     SIDE 1.29
# 110    Hospital B                                   ENTREE 4.29
# 111    Hospital B                                   COFFEE 20OZ
# 112    Hospital B                                   ENTREE 4.99
# 113    Hospital B                            BAKED SWEET POTATO
# 114    Hospital B                               QUESADILLA MEAT
# 115    Hospital A                             ADD A BEVERAGE $1
# 116    Hospital A                                    FRUIT CUPS
# 117    Hospital B                                 BACON 1 SLICE
# 118    Hospital B                                BREAKFAST TACO
# 119    Hospital B                                  GOURMET CAKE
# 120    Hospital B                               QUESADILLA MEAT
# 121    Hospital B                                          EGGS
# 122    Hospital B                                   ENTREE 4.79
# 123    Hospital B                                BREAKFAST TACO
# 124    Hospital B                                       CHORIZO
# 125    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 126    Hospital B                                   FRESH FRUIT
# 127    Hospital B                                 BACON 1 SLICE
# 128    Hospital B                                    HOME FRIES
# 129    Hospital B                                   ENTREE 4.79
# 130    Hospital B                                         FRIES
# 131    Hospital B                                 BURGER CHEESE
# 132    Hospital B                                BACON 3 SLICES
# 133    Hospital B                                  GOURMET CAKE
# 134    Hospital B                                 MEDITERRANEAN
# 135    Hospital B                                BREAKFAST TACO
# 136    Hospital A                             ADD A BEVERAGE $1
# 137    Hospital A                             ADD A BEVERAGE $1
# 138    Hospital A                             ADD A BEVERAGE $1
# 139    Hospital B                                  GOURMET CAKE
# 140    Hospital B                                BACON 3 SLICES
# 141    Hospital B                            FRIES SWEET POTATO
# 142    Hospital B                                BREAKFAST TACO
# 143    Hospital B                            BAKED SWEET POTATO
# 144    Hospital B                                GRILL TOPPINGS
# 145    Hospital B                                BACON 3 SLICES
# 146    Hospital B                                BACON 3 SLICES
# 147    Hospital A                                  ENTREE PASTA
# 148    Hospital B                                   ENTREE 4.79
# 149    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 150    Hospital B                                BREAKFAST TACO
# 151    Hospital B                                   ENTREE 4.99
# 152    Hospital B                                 BURGER CHEESE
# 153    Hospital A                             ADD A BEVERAGE $1
# 154    Hospital B                                          EGGS
# 155    Hospital B                                   CARVED-DELI
# 156    Hospital B                        CHICKEN BREAST GRILLED
# 157    Hospital B                                     SIDE 1.99
# 158    Hospital A                             ADD A BEVERAGE $1
# 159    Hospital B                                       BISCUIT
# 160    Hospital B                                BREAKFAST TACO
# 161    Hospital B                                BREAKFAST TACO
# 162    Hospital B                                   COFFEE 16OZ
# 163    Hospital B                                         FRIES
# 164    Hospital A                             ADD A BEVERAGE $1
# 165    Hospital B                            FRIES SWEET POTATO
# 166    Hospital B                               MIX IT UP SALAD
# 167    Hospital B                                        BURGER
# 168    Hospital A                             ADD A BEVERAGE $1
# 169    Hospital B                               QUESADILLA MEAT
# 170    Hospital B                        ENT -PREMIUM SIDE 1.39
# 171    Hospital B                             CHICKEN TENDERS 3
# 172    Hospital B                                 BACON 1 SLICE
# 173    Hospital B                             DASANI WATER 20OZ
# 174    Hospital B                                GRILLED CHEESE
# 175    Hospital A                             ADD A BEVERAGE $1
# 176    Hospital B                        ENT -PREMIUM SIDE 1.39
# 177    Hospital B                                 BURGER CHEESE
# 178    Hospital B                            BAKED SWEET POTATO
# 179    Hospital B                                  NABISCO OREO
# 180    Hospital B                                BREAKFAST TACO
# 181    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 182    Hospital B                                 BACON 1 SLICE
# 183    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 184    Hospital B                                     TAILGATE.
# 185    Hospital B                             CHICKEN TENDERS 3
# 186    Hospital B                                   COFFEE 20OZ
# 187    Hospital B                                        BURGER
# 188    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 189    Hospital B                            BAKED SWEET POTATO
# 190    Hospital B                                   COFFEE 12OZ
# 191    Hospital A                             ADD A BEVERAGE $1
# 192    Hospital A                             ADD A BEVERAGE $1
# 193    Hospital A                             ADD A BEVERAGE $1
# 194    Hospital B                                     TAILGATE.
# 195    Hospital B                        ENT -PREMIUM SIDE 1.39
# 196    Hospital B                                       CHORIZO
# 197    Hospital B                                  GOURMET CAKE
# 198    Hospital B                                   ENTREE 5.99
# 199    Hospital B                                 SALMON ENTRÉE
# 200    Hospital B                                BURGER VEGGIES
# 201    Hospital B                                 BURGER CHEESE
# 202    Hospital B                                BREAKFAST TACO
# 203    Hospital B                                   ENTREE 4.29
# 204    Hospital B                                     PANCAKE 1
# 205    Hospital B                                       BISCUIT
# 206    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 207    Hospital B                                        BURGER
# 208    Hospital B                                   ENTREE 4.99
# 209    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 210    Hospital B                        ENT -PREMIUM SIDE 1.39
# 211    Hospital B                                        OMELET
# 212    Hospital B                                 BACON 1 SLICE
# 213    Hospital B                                   ENTREE 4.79
# 214    Hospital B                               BISCUIT W/GRAVY
# 215    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 216    Hospital B                                         FRIES
# 217    Hospital B                               BISCUIT W/GRAVY
# 218    Hospital A                                    FRUIT CUPS
# 219    Hospital B                                  GOURMET CAKE
# 220    Hospital B                                     BREAD .99
# 221    Hospital B                               HARD BOILED EGG
# 222    Hospital B                              ENT-BAKED POTATO
# 223    Hospital B                             DASANI WATER 20OZ
# 224    Hospital B                        ENT -PREMIUM SIDE 1.39
# 225    Hospital B                                 MEDITERRANEAN
# 226    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 227    Hospital B                                   ENTREE 4.29
# 228    Hospital B                                  GOURMET CAKE
# 229    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 230    Hospital B                                 MEDITERRANEAN
# 231    Hospital B                                   CARVED-DELI
# 232    Hospital B                                    SABOR CAFE
# 233    Hospital B                                    HOME FRIES
# 234    Hospital B                              ADD BURGER PATTY
# 235    Hospital B                              ENT-BAKED POTATO
# 236    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 237    Hospital A                             ADD A BEVERAGE $1
# 238    Hospital B                                GRILL TOPPINGS
# 239    Hospital B                                 BURGER CHEESE
# 240    Hospital B                                BACON 3 SLICES
# 241    Hospital B                                          EGGS
# 242    Hospital A                            COTTAGE CHEESE CUP
# 243    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 244    Hospital B                                    SABOR CAFE
# 245    Hospital B                                 BURGER CHEESE
# 246    Hospital B                                        OMELET
# 247    Hospital B                             CHICKEN TENDERS 3
# 248    Hospital B                                BACON 3 SLICES
# 249    Hospital A                             ADD A BEVERAGE $1
# 250    Hospital A                             ADD A BEVERAGE $1
# 251    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 252    Hospital B                             DASANI WATER 20OZ
# 253    Hospital B                                   ENTREE 4.99
# 254    Hospital B                                       BISCUIT
# 255    Hospital B                                CEREAL HOT 8OZ
# 256    Hospital B                                 SALMON ENTRÉE
# 257    Hospital B                                   HASH BROWNS
# 258    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 259    Hospital B                                BREAKFAST TACO
# 260    Hospital B                                BACON 3 SLICES
# 261    Hospital B                                   COFFEE 16OZ
# 262    Hospital A                                    FRUIT CUPS
# 263    Hospital B                                  GOURMET CAKE
# 264    Hospital B                               BISCUIT W/GRAVY
# 265    Hospital B                               BISCUIT W/GRAVY
# 266    Hospital B                                   FRESH FRUIT
# 267    Hospital B                                   FRESH FRUIT
# 268    Hospital B                                BREAKFAST TACO
# 269    Hospital B                                   ENTREE 4.79
# 270    Hospital B                              LARGE M&M COOKIE
# 271    Hospital B                                   ENTREE 5.99
# 272    Hospital A                                      TACO BAR
# 273    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 274    Hospital B                         BOTTLE COKE DIET 20OZ
# 275    Hospital B                        ENT -PREMIUM SIDE 1.39
# 276    Hospital B                                  EGG SCRAMBLE
# 277    Hospital B                                   COFFEE 20OZ
# 278    Hospital B                             CHICKEN TENDERS 3
# 279    Hospital B                               QUESADILLA MEAT
# 280    Hospital B                                     SIDE 1.99
# 281    Hospital B                         BOTTLE COKE DIET 20OZ
# 282    Hospital B                                 BURGER CHEESE
# 283    Hospital B                                   ENTREE 4.99
# 284    Hospital A                             ADD A BEVERAGE $1
# 285    Hospital B                                BREAKFAST TACO
# 286    Hospital B                                       BISCUIT
# 287    Hospital B                                        BURGER
# 288    Hospital B                                    SABOR CAFE
# 289    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 290    Hospital B                                   BOTTLE COKE
# 291    Hospital B                                        BURGER
# 292    Hospital B                               BISCUIT W/GRAVY
# 293    Hospital B                                   CARVED-DELI
# 294    Hospital B                                   ENTREE 5.99
# 295    Hospital B                                   ENTREE 5.99
# 296    Hospital B                                   CARVED-DELI
# 297    Hospital B                               BISCUIT W/GRAVY
# 298    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 299    Hospital B                                          EGGS
# 300    Hospital B                                   COFFEE 16OZ
# 301    Hospital B                                   ENTREE 5.99
# 302    Hospital B                               BISCUIT W/GRAVY
# 303    Hospital B                                       BISCUIT
# 304    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 305    Hospital B                                  GOURMET CAKE
# 306    Hospital B                                     SIDE 1.99
# 307    Hospital B                                     SIDE 1.99
# 308    Hospital B                                    HOME FRIES
# 309    Hospital B                             QUESADILLA CHEESE
# 310    Hospital B                                        BURGER
# 311    Hospital B                                   CARVED-DELI
# 312    Hospital B           TOPO CHICO TWIST OF GRAPEFRUIT 20OZ
# 313    Hospital B                                CEREAL HOT 8OZ
# 314    Hospital B                                         FRIES
# 315    Hospital B                                   FRESH FRUIT
# 316    Hospital B                                   ENTREE 4.29
# 317    Hospital B                                BREAKFAST TACO
# 318    Hospital B                                 BURGER CHEESE
# 319    Hospital B                                 BURGER CHEESE
# 320    Hospital B                               MIX IT UP SALAD
# 321    Hospital A                             ADD A BEVERAGE $1
# 322    Hospital B                                     BREAD .59
# 323    Hospital B                                   COFFEE 16OZ
# 324    Hospital B                                   ONION RINGS
# 325    Hospital B                             DASANI WATER 20OZ
# 326    Hospital B                                     SIDE 1.99
# 327    Hospital B                                BREAKFAST TACO
# 328    Hospital B                                        BURGER
# 329    Hospital B  BOTTLE GOLD PEAK UNSWEETENED ICED TEA 18.5OZ
# 330    Hospital B                                    ADD CHEESE
# 331    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 332    Hospital B                                   COFFEE 12OZ
# 333    Hospital B                                 BACON 1 SLICE
# 334    Hospital B                                 BURGER TURKEY
# 335    Hospital B                            FRIES SWEET POTATO
# 336    Hospital B                                GRILL TOPPINGS
# 337    Hospital B                                BACON 3 SLICES
# 338    Hospital B                                 BURGER CHEESE
# 339    Hospital B                                 SAUSAGE PATTY
# 340    Hospital B                                 BACON 1 SLICE
# 341    Hospital B                                 SALMON ENTRÉE
# 342    Hospital B                                  EGG SCRAMBLE
# 343    Hospital B                                 BURGER CHEESE
# 344    Hospital B                                   COFFEE 12OZ
# 345    Hospital B           CORE POWER HP MILK SHAKE CHOC 14 OZ
# 346    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 347    Hospital B                                   ONION RINGS
# 348    Hospital B                                     SIDE 1.29
# 349    Hospital B                                         FRIES
# 350    Hospital B                                CEREAL HOT 8OZ
# 351    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 352    Hospital B                               QUESADILLA MEAT
# 353    Hospital B                                   BOTTLE COKE
# 354    Hospital B                        CHICKEN BREAST GRILLED
# 355    Hospital B                                   BOTTLE COKE
# 356    Hospital A                             ADD A BEVERAGE $1
# 357    Hospital B                                     BREAD .99
# 358    Hospital B                        ENT -PREMIUM SIDE 1.39
# 359    Hospital B                                 SMARTWATER 1L
# 360    Hospital B                                   ENTREE 4.79
# 361    Hospital B                            BAKED SWEET POTATO
# 362    Hospital B                                 IMP-CANDY BAR
# 363    Hospital B                                         FRIES
# 364    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 365    Hospital B                                       CHORIZO
# 366    Hospital B                                BACON 3 SLICES
# 367    Hospital B                               HARD BOILED EGG
# 368    Hospital B                                 SMARTWATER 1L
# 369    Hospital B                                   COFFEE 20OZ
# 370    Hospital B                                   ENTREE 4.29
# 371    Hospital A                             ADD A BEVERAGE $1
# 372    Hospital B                                BREAKFAST TACO
# 373    Hospital B                             CHICKEN TENDERS 3
# 374    Hospital B                                   CARVED-DELI
# 375    Hospital B                               BISCUIT W/GRAVY
# 376    Hospital B                                 SALMON ENTRÉE
# 377    Hospital B                               MIX IT UP SALAD
# 378    Hospital B                               MIX IT UP SALAD
# 379    Hospital B                                          EGGS
# 380    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 381    Hospital B                                  GOURMET CAKE
# 382    Hospital A                             ADD A BEVERAGE $1
# 383    Hospital B                             QUESADILLA CHEESE
# 384    Hospital B                             CHICKEN TENDERS 3
# 385    Hospital B                                CEREAL HOT 8OZ
# 386    Hospital B                                    HOME FRIES
# 387    Hospital B                                 REFRIED BEANS
# 388    Hospital A                             ADD A BEVERAGE $1
# 389    Hospital B                                  GOURMET CAKE
# 390    Hospital B  BOTTLE GOLD PEAK UNSWEETENED ICED TEA 18.5OZ
# 391    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 392    Hospital B       CHIPS MISS VICKIES SEA SALT VIN 1 3/8OZ
# 393    Hospital B                            AHA-CITRUS& G. TEA
# 394    Hospital B                         BOTTLE COKE DIET 20OZ
# 395    Hospital B                                  GOURMET CAKE
# 396    Hospital A                             ADD A BEVERAGE $1
# 397    Hospital B                                   COFFEE 12OZ
# 398    Hospital A                                    FRUIT CUPS
# 399    Hospital B                               MIX IT UP SALAD
# 400    Hospital B                                CEREAL HOT 8OZ
# 401    Hospital B                 TOPO CHICO TWIST OF LIME 20OZ
# 402    Hospital B                                BREAKFAST TACO
# 403    Hospital B                                 SMARTWATER 1L
# 404    Hospital B                                 BURGER CHEESE
# 405    Hospital B                                 BURGER CHEESE
# 406    Hospital B                                   FRESH FRUIT
# 407    Hospital B                                         FRIES
# 408    Hospital B                             DASANI WATER 20OZ
# 409    Hospital B                                       BISCUIT
# 410    Hospital B                                   COFFEE 16OZ
# 411    Hospital B                                   COFFEE 12OZ
# 412    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 413    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 414    Hospital B                                   FRESH FRUIT
# 415    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 416    Hospital B                                 BURGER CHEESE
# 417    Hospital B                 BOTTLEAHA SPARKLING BERRY/POM
# 418    Hospital B                                   ENTREE 4.29
# 419    Hospital B                                  GOURMET CAKE
# 420    Hospital B                         BOTTLE COKE DIET 20OZ
# 421    Hospital B                         BOTTLE COKE DIET 20OZ
# 422    Hospital B                        ENT -PREMIUM SIDE 1.39
# 423    Hospital B                                 SAUSAGE PATTY
# 424    Hospital B                                GRILLED CHEESE
# 425    Hospital B                            BOTTLE SPRITE 20OZ
# 426    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 427    Hospital B                                 BACON 1 SLICE
# 428    Hospital B                            AHA-CITRUS& G. TEA
# 429    Hospital B                                   COFFEE 12OZ
# 430    Hospital B                                   COFFEE 12OZ
# 431    Hospital B                                   COFFEE 16OZ
# 432    Hospital B                                  EGG SCRAMBLE
# 433    Hospital B                                          EGGS
# 434    Hospital B                                 BURGER CHEESE
# 435    Hospital B                                BACON 3 SLICES
# 436    Hospital A                               ADD A 12OZ COFF
# 437    Hospital B                                   ENTREE 4.79
# 438    Hospital B                                 SMARTWATER 1L
# 439    Hospital B                                 BURGER CHEESE
# 440    Hospital B                                 BACON 1 SLICE
# 441    Hospital B           TOPO CHICO TWIST OF GRAPEFRUIT 20OZ
# 442    Hospital B                                         FRIES
# 443    Hospital B                                 BACON 1 SLICE
# 444    Hospital B                                    HOME FRIES
# 445    Hospital B                                         FRIES
# 446    Hospital B                                   ENTREE 5.99
# 447    Hospital B                                       BISCUIT
# 448    Hospital B                                BACON 3 SLICES
# 449    Hospital A                               SUPERFOOD SALAD
# 450    Hospital B                                   ENTREE 4.79
# 451    Hospital B                                 MEDITERRANEAN
# 452    Hospital B                                     BREAD .59
# 453    Hospital B                                  GOURMET CAKE
# 454    Hospital B  J&O -SANDWICH TURKEY & PROVOLONE ON 12 GRAIN
# 455    Hospital A                                    2 FOR 2.49
# 456    Hospital B                                          EGGS
# 457    Hospital B                            AHA-CITRUS& G. TEA
# 458    Hospital B                            FRIES SWEET POTATO
# 459    Hospital B                             DASANI WATER 20OZ
# 460    Hospital B                                       HOT DOG
# 461    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 462    Hospital B                                 SAUSAGE PATTY
# 463    Hospital B                                BREAKFAST TACO
# 464    Hospital B             BOTTLEAHA SPARKLING LM/WATERMELOM
# 465    Hospital B                                         FRIES
# 466    Hospital B                                   CARVED-DELI
# 467    Hospital A                             ADD A BEVERAGE $1
# 468    Hospital B  BOTTLE GOLD PEAK UNSWEETENED ICED TEA 18.5OZ
# 469    Hospital B                              ENT-BAKED POTATO
# 470    Hospital B                                   ENTREE 4.99
# 471    Hospital B                                     BREAD .99
# 472    Hospital B                                BACON 3 SLICES
# 473    Hospital B                                BREAKFAST TACO
# 474    Hospital B                                        OMELET
# 475    Hospital B                                       CHORIZO
# 476    Hospital B                                     BREAD .59
# 477    Hospital B                                BURGER VEGGIES
# 478    Hospital B                              ENT-BAKED POTATO
# 479    Hospital B                                   ENTREE 4.79
# 480    Hospital B                                   CARVED-DELI
# 481    Hospital B                                   STIR FRIDAY
# 482    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 483    Hospital B                                 BURGER CHEESE
# 484    Hospital B                                BREAKFAST TACO
# 485    Hospital B                            BAKED SWEET POTATO
# 486    Hospital B                                 SAUSAGE PATTY
# 487    Hospital B                            BAKED SWEET POTATO
# 488    Hospital B                                  FRENCH TOAST
# 489    Hospital B                                BACON 3 SLICES
# 490    Hospital A                                    FRUIT CUPS
# 491    Hospital B                                GRILL TOPPINGS
# 492    Hospital B                              LARGE M&M COOKIE
# 493    Hospital B                                   ENTREE 4.29
# 494    Hospital B                               HARD BOILED EGG
# 495    Hospital B                         BOTTLE COKE DIET 20OZ
# 496    Hospital B                                 IMP-CANDY BAR
# 497    Hospital B                            BAKED SWEET POTATO
# 498    Hospital A                             ADD A BEVERAGE $1
# 499    Hospital B                                     BREAD .99
# 500    Hospital B                              LARGE M&M COOKIE
# 501    Hospital B                                BURGER VEGGIES
# 502    Hospital B                                   ENTREE 4.99
# 503    Hospital B                             CHICKEN TENDERS 3
# 504    Hospital B                CHIPS MISS VICKIES JAL 1 3/8OZ
# 505    Hospital B                                   COFFEE 12OZ
# 506    Hospital B                             MISS VICKIES ORIG
# 507    Hospital B                 CHIP DORITO COOL RANCH 1.74OZ
# 508    Hospital B                                          EGGS
# 509    Hospital B                                   BOTTLE COKE
# 510    Hospital B                     CHIP DORITOS NACHO CHEESE
# 511    Hospital B                                  TACO TUESDAY
# 512    Hospital A                               CARVED DELI SHL
# 513    Hospital B                              ENT-BAKED POTATO
# 514    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 515    Hospital B                                  FRENCH TOAST
# 516    Hospital B                             CHICKEN TENDERS 3
# 517    Hospital B                              LARGE M&M COOKIE
# 518    Hospital B                                     SIDE 1.99
# 519    Hospital B                                BURGER VEGGIES
# 520    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 521    Hospital B                                   BOTTLE COKE
# 522    Hospital B                                BACON 3 SLICES
# 523    Hospital B                              LARGE M&M COOKIE
# 524    Hospital B                              ADD BURGER PATTY
# 525    Hospital B                                  GOURMET CAKE
# 526    Hospital B                                BACON 3 SLICES
# 527    Hospital A                         CHICKEN TENDER BASKET
# 528    Hospital B                                   COFFEE 20OZ
# 529    Hospital B                                   FRESH FRUIT
# 530    Hospital B                                          EGGS
# 531    Hospital B                                       CHORIZO
# 532    Hospital B                                CEREAL HOT 8OZ
# 533    Hospital A                                    FRUIT CUPS
# 534    Hospital B                                   FRESH FRUIT
# 535    Hospital B                                GRILLED CHEESE
# 536    Hospital B                              ADD BURGER PATTY
# 537    Hospital B                                  GOURMET CAKE
# 538    Hospital B                   BOTTLE DR. PEPPER DIET 20OZ
# 539    Hospital B                                   ENTREE 4.99
# 540    Hospital B                                  GOURMET CAKE
# 541    Hospital B                                          EGGS
# 542    Hospital B           CORE POWER HP MILK SHAKE CHOC 14 OZ
# 543    Hospital B                            BAKED SWEET POTATO
# 544    Hospital B                                   ENTREE 4.79
# 545    Hospital B                                 BURGER CHEESE
# 546    Hospital B                                GRILL TOPPINGS
# 547    Hospital B                            BAKED SWEET POTATO
# 548    Hospital B                             DASANI WATER 20OZ
# 549    Hospital A                               CARVED DELI SHL
# 550    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 551    Hospital B                                        BURGER
# 552    Hospital A                                    FRUIT CUPS
# 553    Hospital B                                   STIR FRIDAY
# 554    Hospital A                                    FRUIT CUPS
# 555    Hospital A                             ADD A BEVERAGE $1
# 556    Hospital B                                 BURGER CHEESE
# 557    Hospital B                                   ENTREE 4.99
# 558    Hospital B                               BISCUIT W/GRAVY
# 559    Hospital B                                   FRESH FRUIT
# 560    Hospital B                                        BURGER
# 561    Hospital B                            BOTTLE SPRITE 20OZ
# 562    Hospital B                                GRILLED CHEESE
# 563    Hospital B                                        BURGER
# 564    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 565    Hospital B                                        OMELET
# 566    Hospital B                                   ENTREE 4.79
# 567    Hospital B                                   BOTTLE COKE
# 568    Hospital B                                   HASH BROWNS
# 569    Hospital B                            FRIES SWEET POTATO
# 570    Hospital B                                 MEDITERRANEAN
# 571    Hospital B                                         MUNCH
# 572    Hospital B                                 BURGER CHEESE
# 573    Hospital B                         BOTTLE COKE DIET 20OZ
# 574    Hospital B                             CHICKEN TENDERS 3
# 575    Hospital B                                   CARVED-DELI
# 576    Hospital B                                 BURGER CHEESE
# 577    Hospital B                                        OMELET
# 578    Hospital B                                        BURGER
# 579    Hospital B                                   COFFEE 16OZ
# 580    Hospital B                                 BURGER CHEESE
# 581    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 582    Hospital B                                  GOURMET CAKE
# 583    Hospital B                                   HASH BROWNS
# 584    Hospital B                 CHIP DORITO COOL RANCH 1.74OZ
# 585    Hospital B                        CHICKEN BREAST GRILLED
# 586    Hospital B                                  GOURMET CAKE
# 587    Hospital B                                         FRIES
# 588    Hospital B                            BAKED SWEET POTATO
# 589    Hospital B                                   NOODLE SHOP
# 590    Hospital B                                  EGG SCRAMBLE
# 591    Hospital B                 CHIP DORITO COOL RANCH 1.74OZ
# 592    Hospital A                             ADD A BEVERAGE $1
# 593    Hospital B                                  GOURMET CAKE
# 594    Hospital B                                 BURGER CHEESE
# 595    Hospital B                                 BURGER CHEESE
# 596    Hospital B                                 BACON 1 SLICE
# 597    Hospital B                            FRIES SWEET POTATO
# 598    Hospital B           CORE POWER HP MILK SHAKE CHOC 14 OZ
# 599    Hospital B                         BOTTLE COKE DIET 20OZ
# 600    Hospital A                               ASIAN MIX IT UP
# 601    Hospital B                                       BISCUIT
# 602    Hospital B                 BOTTLEAHA SPARKLING BERRY/POM
# 603    Hospital B            CORE POWER HP MILK SHAKE VAN 14 OZ
# 604    Hospital B                                   COFFEE 16OZ
# 605    Hospital B                                BACON 3 SLICES
# 606    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 607    Hospital B                        ENT -PREMIUM SIDE 1.39
# 608    Hospital A                         BVC-RED BULL TROPICAL
# 609    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 610    Hospital B                                   COFFEE 16OZ
# 611    Hospital B                                 BURGER CHEESE
# 612    Hospital B                                     SIDE 1.29
# 613    Hospital B                                   ENTREE 4.99
# 614    Hospital B           CORE POWER HP MILK SHAKE CHOC 14 OZ
# 615    Hospital B                         BOTTLE COKE DIET 20OZ
# 616    Hospital B                                   ENTREE 4.99
# 617    Hospital B                                        BURGER
# 618    Hospital B                                RECHARGECOOKIE
# 619    Hospital B                              LARGE M&M COOKIE
# 620    Hospital B                         BOTTLE COKE DIET 20OZ
# 621    Hospital B                                 BACON 1 SLICE
# 622    Hospital B                                GRILLED CHEESE
# 623    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 624    Hospital B                                   ENTREE 5.99
# 625    Hospital B                                        BURGER
# 626    Hospital B                                         FRIES
# 627    Hospital B                                        OMELET
# 628    Hospital B                                         FRIES
# 629    Hospital B                                BACON 3 SLICES
# 630    Hospital B                                         FRIES
# 631    Hospital B                                BREAKFAST TACO
# 632    Hospital B                                     SIDE 1.29
# 633    Hospital B                                BACON 3 SLICES
# 634    Hospital B                                           BLT
# 635    Hospital B                             QUESADILLA CHEESE
# 636    Hospital A                                    FRUIT CUPS
# 637    Hospital B                                   COFFEE 20OZ
# 638    Hospital B                                   BOTTLE COKE
# 639    Hospital B                       SANDWICH CHICKEN BREAST
# 640    Hospital B                              ENT-BAKED POTATO
# 641    Hospital B                                CEREAL HOT 8OZ
# 642    Hospital B                                 PASTA STATION
# 643    Hospital B                               BISCUIT W/GRAVY
# 644    Hospital B                 BOTTLEAHA SPARKLING BERRY/POM
# 645    Hospital B                                   ENTREE 4.29
# 646    Hospital B                                 BACON 1 SLICE
# 647    Hospital A                                      BROWNIES
# 648    Hospital B                                   FRESH FRUIT
# 649    Hospital B                                 SMARTWATER 1L
# 650    Hospital B                                   ONION RINGS
# 651    Hospital B                                 BURGER CHEESE
# 652    Hospital B                                    HOME FRIES
# 653    Hospital B                                 MEDITERRANEAN
# 654    Hospital B                                 BURGER TURKEY
# 655    Hospital B                                BREAKFAST TACO
# 656    Hospital B                                    BREAD 1.09
# 657    Hospital A                                       COOKIES
# 658    Hospital B                        ENT -PREMIUM SIDE 1.39
# 659    Hospital B                                   COFFEE 16OZ
# 660    Hospital B                                        BURGER
# 661    Hospital B                                         MIGAS
# 662    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 663    Hospital B                                 BURGER TURKEY
# 664    Hospital B                               CUCINA ITALIANO
# 665    Hospital B                        COKE ZERO BOTTLE 20 OZ
# 666    Hospital B                                   COFFEE 16OZ
# 667    Hospital B                                 SAUSAGE GRAVY
# 668    Hospital B                             QUESADILLA CHEESE
# 669    Hospital B                                   STIR FRIDAY
# 670    Hospital B                                   ENTREE 4.99
# 671    Hospital B                     CHIP DORITOS NACHO CHEESE
# 672    Hospital B                                GRILL TOPPINGS
# 673    Hospital B                                CEREAL HOT 8OZ
# 674    Hospital B                             CHICKEN TENDERS 3
# 675    Hospital B                                 MEDITERRANEAN
# 676    Hospital B                         BOTTLE COKE DIET 20OZ
# 677    Hospital A                             ADD A BEVERAGE $1
# 678    Hospital A                                      BROWNIES
# 679    Hospital B                               CUCINA ITALIANO
# 680    Hospital B                       SANDWICH CHICKEN BREAST
# 681    Hospital B                             CHICKEN TENDERS 3
# 682    Hospital B                            FRIES SWEET POTATO
# 683    Hospital B                                          EGGS
# 684    Hospital B             BVC -TOPOCHICO MINERAL WATER-20OZ
# 685    Hospital B                            AHA-CITRUS& G. TEA
# 686    Hospital B                             DASANI WATER 20OZ
# 687    Hospital B                                   CARVED-DELI
# 688    Hospital A                                      BROWNIES
# 689    Hospital B                                 BURGER CHEESE
# 690    Hospital A                                  ADD A COOKIE
# 691    Hospital B                                 BURGER CHEESE
# 692    Hospital B                                       BISCUIT
# 693    Hospital A                                    FRUIT CUPS
# 694    Hospital B                                BACON 3 SLICES
# 695    Hospital A                             ADD A BEVERAGE $1
# 696    Hospital B                                          EGGS
# 697    Hospital B                                  EGG SCRAMBLE
# 698    Hospital B                                 PASTA STATION
# 699    Hospital B                                 BURGER CHEESE
# 700    Hospital B           CORE POWER HP MILK SHAKE CHOC 14 OZ
# 701    Hospital B                                GRILLED CHEESE
# 702    Hospital A                                    GREEK BOWL
# 703    Hospital B                                  GOURMET CAKE
# 704    Hospital B                                   FRESH FRUIT
# 705    Hospital B                  FSTG TORTILLA CHIPS JALAPENO
# 706    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 707    Hospital A                             ADD A BEVERAGE $1
# 708    Hospital B                                     BREAD .99
# 709    Hospital B                                   FRESH FRUIT
# 710    Hospital B                                   ENTREE 4.29
# 711    Hospital B                                        OMELET
# 712    Hospital B                        BOTTLE DR. PEPPER 20OZ
# 713    Hospital B                CANDY REESE PEANUT BUTTER CUPS
# ...
# 684                                          SALT  Hospital B          2
# 685                               CEREAL HOT 12OZ  Hospital B          1
# 686                                LOUISANA SAUCE  Hospital B          2
# 687                         STRWBRRY FRENCH TOAST  Hospital A          4
# 688                                       ORANGES  Hospital A          1
# 689           DEEP RIVER CHIPS ZESTY JALAPENO 2OZ  Hospital B          1
# 690                   CHIP CHEETOS CRNCHYHOT LIME  Hospital B          1
# 691                 CEREAL BOX RAISIN BRAN 1.52OZ  Hospital A          1
# 692                KELLOGGS CEREAL FROSTED FLAKES  Hospital B          1
# 693                            ADDITIONAL TOPPING  Hospital A          3
# 694                    PORTION CUP SALAD DRESSING  Hospital B          1
# 695                                 ADD CONDIMENT  Hospital B         19
# 696                                 ADD GUACAMOLE  Hospital A          2
# 697                         ONDEMAND EXTRA SAUCE?  Hospital A          2
# 698                             TOILET PAPER ROLL  Hospital B          2
# 699                                      CRACKERS  Hospital B          1
#
#      Total Revenue
# 0     24841.740061
# 1     23938.199787
# 2     22554.059438
# 3     20468.700054
# 4     18960.269457
# 5     17754.419186
# 6     16603.589509
# 7     15222.619879
# 8     14850.899982
# 9     14045.739859
# 10    13567.019611
# 11    13333.409818
# 12    11162.029680
# 13    11052.719917
# 14    10949.000000
# 15     9629.040197
# 16     9215.709742
# 17     8752.579821
# 18     8624.939745
# 19     8624.139856
# 20     8131.959844
# 21     8014.619694
# 22     7928.160036
# 23     7709.969748
# 24     7647.119774
# 25     7513.489875
# 26     7423.990224
# 27     7346.319878
# 28     6492.319967
# 29     6298.089936
# 30     6265.300176
# 31     5962.179803
# 32     5920.589830
# 33     5646.249939
# 34     5521.900032
# 35     5377.269846
# 36     5070.520023
# 37     5065.659855
# 38     4911.690012
# 39     4650.330173
# 40     4560.570011
# 41     4467.060013
# 42     4424.669855
# 43     4363.439980
# 44     3793.680037
# 45     3741.200018
# 46     3651.479973
# 47     3452.889894
# 48     3283.960020
# 49     3259.919907
# 50     3254.900069
# 51     3227.959908
# 52     3216.779976
# 53     3163.420010
# 54     3160.779903
# 55     3124.089911
# 56     3104.400013
# 57     3092.550083
# 58     3080.139843
# 59     3041.119949
# 60     3013.779876
# 61     2686.939884
# 62     2658.640013
# 63     2604.739925
# 64     2564.789927
# 65     2547.200012
# 66     2542.290010
# 67     2540.170069
# 68     2521.080012
# 69     2482.630093
# 70     2337.399940
# 71     2322.540077
# 72     2280.459951
# 73     2229.519943
# 74     2176.720007
# 75     2009.989972
# 76     1987.379917
# 77     1979.380007
# 78     1962.149982
# 79     1933.579945
# 80     1906.619944
# 81     1866.620009
# 82     1818.179958
# 83     1806.839987
# 84     1769.879948
# 85     1747.819987
# 86     1714.229987
# 87     1630.559952
# 88     1533.840006
# 89     1507.379950
# 90     1479.820018
# 91     1470.159958
# 92     1420.440003
# 93     1414.229959
# 94     1383.689947
# 95     1366.060051
# 96     1361.519943
# 97     1327.559995
# 98     1280.430020
# 99     1273.590027
# 100    1258.739990
# 101    1253.049978
# 102    1251.360012
# 103    1245.740005
# 104    1245.590045
# 105    1234.169991
# 106    1214.709960
# 107    1214.479965
# 108    1203.989954
# 109    1184.860018
# 110    1147.330041
# 111    1140.760029
# 112    1118.599968
# 113    1094.500004
# 114    1084.800032
# 115    1083.449965
# 116    1066.549967
# 117    1048.279976
# 118    1012.969954
# 119    1007.379959
# 120     999.179958
# 121     998.749971
# 122     970.549989
# 123     966.239960
# 124     949.620002
# 125     929.069979
# 126     921.690002
# 127     916.469965
# 128     892.379991
# 129     885.859962
# 130     880.739971
# 131     835.289965
# 132     829.830004
# 133     812.699994
# 134     778.439964
# 135     777.400002
# 136     773.449965
# 137     746.639969
# 138     744.689979
# 139     741.520003
# 140     741.509977
# 141     737.179981
# 142     724.679970
# 143     703.480026
# 144     693.869988
# 145     691.579988
# 146     690.030007
# 147     678.639969
# 148     676.000000
# 149     659.379999
# 150     658.899975
# 151     657.999992
# 152     654.029981
# 153     646.750003
# 154     639.780001
# 155     631.679993
# 156     609.259995
# 157     594.919994
# 158     592.020002
# 159     591.709982
# 160     575.459994
# 161     554.609994
# 162     536.479996
# 163     530.409986
# 164     526.899996
# 165     523.250002
# 166     518.959977
# 167     518.469995
# 168     513.760017
# 169     505.079979
# 170     505.079979
# 171     498.750001
# 172     494.009977
# 173     490.209994
# 174     489.299984
# 175     485.459988
# 176     480.059996
# 177     480.059996
# 178     469.059978
# 179     466.199985
# 180     465.090006
# 181     461.229982
# 182     458.489988
# 183     445.060016
# 184     444.819993
# 185     443.409995
# 186     443.079982
# 187     442.889985
# 188     437.569995
# 189     424.149981
# 190     421.590001
# 191     421.119995
# 192     418.950001
# 193     414.169981
# 194     413.079979
# 195     412.000000
# 196     402.479988
# 197     399.499989
# 198     396.969988
# 199     390.880002
# 200     389.219982
# 201     387.030001
# 202     385.029996
# 203     383.199997
# 204     375.549988
# 205     372.270000
# 206     362.730011
# 207     358.609996
# 208     357.419988
# 209     354.449997
# 210     352.029989
# 211     345.510002
# 212     340.260007
# 213     338.300002
# 214     338.000011
# 215     335.439987
# 216     333.869992
# 217     333.229992
# 218     332.289996
# 219     331.519989
# 220     330.870007
# 221     330.219987
# 222     329.339985
# 223     327.180001
# 224     326.679991
# 225     325.259997
# 226     324.370002
# 227     322.740003
# 228     321.389986
# 229     319.200001
# 230     318.920015
# 231     315.919990
# 232     315.810006
# 233     315.589988
# 234     314.369986
# 235     312.929987
# 236     311.850000
# 237     311.359997
# 238     304.439991
# 239     298.800001
# 240     297.139994
# 241     295.409991
# 242     293.509989
# 243     289.519997
# 244     287.669991
# 245     284.429987
# 246     282.869987
# 247     279.180002
# 248     278.689993
# 249     277.089995
# 250     276.390001
# 251     275.219998
# 252     272.220001
# 253     272.200006
# 254     271.049997
# 255     270.300006
# 256     265.639996
# 257     265.619991
# 258     262.350003
# 259     259.159989
# 260     258.539998
# 261     255.719993
# 262     253.890001
# 263     252.399995
# 264     251.639992
# 265     251.229992
# 266     251.160001
# 267     250.139997
# 268     249.499989
# 269     247.380001
# 270     247.380001
# 271     243.020003
# 272     242.559998
# 273     239.200001
# 274     236.879997
# 275     233.099993
# 276     231.709993
# 277     230.909995
# 278     230.669992
# 279     230.669992
# 280     230.509993
# 281     230.509992
# 282     229.539989
# 283     225.719991
# 284     225.179998
# 285     224.749994
# 286     223.679993
# 287     222.480001
# 288     221.959995
# 289     221.789994
# 290     221.629992
# 291     219.559990
# 292     217.349998
# 293     216.870001
# 294     215.460001
# 295     214.969993
# 296     214.569990
# 297     214.439999
# 298     210.940001
# 299     209.300001
# 300     206.960001
# 301     205.910001
# 302     204.659998
# 303     203.940002
# 304     202.229994
# 305     195.719994
# 306     194.609991
# 307     191.659994
# 308     191.360001
# 309     183.889994
# 310     182.309995
# 311     181.739994
# 312     179.400001
# 313     179.190002
# 314     176.969998
# 315     175.419996
# 316     171.570000
# 317     170.939994
# 318     170.430001
# 319     169.320001
# 320     169.000006
# 321     167.789998
# 322     167.719994
# 323     167.699995
# 324     167.620006
# 325     167.580000
# 326     167.520000
# 327     164.699993
# 328     164.030000
# 329     161.850001
# 330     161.460001
# 331     160.929994
# 332     159.679993
# 333     157.989995
# 334     155.739994
# 335     155.709997
# 336     154.629998
# 337     154.629998
# 338     153.710003
# 339     152.490000
# 340     152.490000
# 341     151.199999
# 342     150.570000
# 343     150.070000
# 344     149.250001
# 345     146.789995
# 346     145.340005
# 347     144.759998
# 348     143.639999
# 349     143.550001
# 350     142.309996
# 351     141.960005
# 352     140.029994
# 353     139.920003
# 354     139.859997
# 355     139.600000
# 356     137.769995
# 357     137.249994
# 358     136.710001
# 359     135.730003
# 360     135.630001
# 361     134.189999
# 362     132.210004
# 363     131.889997
# 364     131.779995
# 365     129.350001
# 366     129.130001
# 367     128.440004
# 368     125.430004
# 369     125.370000
# 370     124.749994
# 371     124.670000
# 372     123.690000
# 373     123.690000
# 374     119.340004
# 375     117.000000
# 376     116.349998
# 377     111.750001
# 378     110.260000
# 379     109.799995
# 380     109.789996
# 381     108.779996
# 382     108.480003
# 383     108.419999
# 384     107.460001
# 385     106.920001
# 386     106.019999
# 387     105.639999
# 388     104.859997
# 389     104.849997
# 390     102.930003
# 391     102.659995
# 392     101.400003
# 393     101.150004
# 394     100.619997
# 395     100.280003
# 396     100.169999
# 397      97.720000
# 398      96.929998
# 399      95.940001
# 400      95.760000
# 401      94.379999
# 402      94.230000
# 403      94.010001
# 404      92.380000
# 405      91.770000
# 406      91.289998
# 407      90.349999
# 408      90.349999
# 409      89.749998
# 410      89.540002
# 411      89.400001
# 412      88.560001
# 413      87.889997
# 414      86.700003
# 415      86.240000
# 416      86.130001
# 417      85.140001
# 418      84.660000
# 419      81.950000
# 420      79.979998
# 421      79.839996
# 422      79.800000
# 423      79.800000
# 424      75.810000
# 425      75.239997
# 426      75.059999
# 427      74.460002
# 428      74.250000
# 429      74.189999
# 430      74.090003
# 431      73.290000
# 432      72.210000
# 433      71.939999
# 434      71.919998
# 435      71.909998
# 436      71.760000
# 437      71.760000
# 438      70.100000
# 439      69.940001
# 440      69.499999
# 441      68.909999
# 442      67.339998
# 443      67.230000
# 444      66.310000
# 445      65.910002
# 446      65.879997
# 447      65.849998
# 448      65.440002
# 449      64.749998
# 450      63.840000
# 451      63.680000
# 452      63.680000
# 453      61.679998
# 454      60.859999
# 455      60.659998
# 456      60.480000
# 457      60.059999
# 458      59.899998
# 459      59.899998
# 460      59.899998
# 461      59.539999
# 462      59.180001
# 463      57.710000
# 464      57.270000
# 465      56.680002
# 466      56.490001
# 467      56.490001
# 468      55.840000
# 469      55.770002
# 470      55.720000
# 471      54.889997
# 472      54.810000
# 473      53.939999
# 474      53.820000
# 475      53.820000
# 476      53.789999
# 477      52.500000
# 478      52.350000
# 479      51.870000
# 480      50.880001
# 481      49.899998
# 482      49.140000
# 483      48.830000
# 484      48.730000
# 485      48.420001
# 486      47.880000
# 487      46.680001
# 488      46.539999
# 489      46.240002
# 490      45.799999
# 491      44.909998
# 492      44.899998
# 493      44.200000
# 494      43.780000
# 495      43.440000
# 496      43.040001
# 497      42.399998
# 498      41.939999
# 499      41.929998
# 500      41.860000
# 501      41.219999
# 502      40.560001
# 503      39.840000
# 504      38.240002
# 505      37.660001
# 506      36.270000
# 507      35.910000
# 508      34.949999
# 509      34.900000
# 510      34.650000
# 511      34.509999
# 512      33.540001
# 513      31.959999
# 514      31.450000
# 515      30.580000
# 516      29.949999
# 517      29.939999
# 518      29.850000
# 519      29.190000
# 520      28.730001
# 521      28.710001
# 522      27.920000
# 523      26.910000
# 524      26.910000
# 525      26.460001
# 526      25.899999
# 527      25.500000
# 528      25.059999
# 529      24.949999
# 530      24.949999
# 531      24.900000
# 532      24.900000
# 533      24.430000
# 534      23.969999
# 535      23.959999
# 536      23.760000
# 537      22.469999
# 538      22.350000
# 539      21.480000
# 540      21.140000
# 541      21.070000
# 542      20.850000
# 543      20.789999
# 544      19.959999
# 545      19.740000
# 546      19.690000
# 547      19.559999
# 548      19.530000
# 549      18.960001
# 550      18.870000
# 551      17.969999
# 552      17.969999
# 553      17.490000
# 554      16.900001
# 555      16.680000
# 556      16.660001
# 557      16.560000
# 558      16.469999
# 559      16.360001
# 560      15.840000
# 561      15.840000
# 562      15.520000
# 563      15.290000
# 564      15.290000
# 565      14.980000
# 566      14.950000
# 567      14.940000
# 568      14.940000
# 569      14.900000
# 570      14.820000
# 571      14.370000
# 572      14.280001
# 573      13.980000
# 574      13.950000
# 575      13.569999
# 576      13.410000
# 577      12.720000
# 578      12.530000
# 579      12.510000
# 580      12.020000
# 581      11.980000
# 582      11.980000
# 583      11.970000
# 584      11.970000
# 585      11.940000
# 586      11.760000
# 587      11.670000
# 588      11.450000
# 589      11.340000
# 590      10.890000
# 591      10.740000
# 592      10.470000
# 593      10.450000
# 594      10.290000
# 595       9.950000
# 596       9.900000
# 597       9.900000
# 598       9.870000
# 599       9.030000
# 600       8.990000
# 601       8.980000
# 602       8.970000
# 603       8.940000
# 604       8.910000
# 605       8.670000
# 606       8.580000
# 607       8.580000
# 608       8.490000
# 609       8.070000
# 610       8.070000
# 611       7.980000
# 612       7.950000
# 613       7.580000
# 614       7.490000
# 615       7.450000
# 616       7.450000
# 617       7.180000
# 618       7.140000
# 619       7.020000
# 620       6.990000
# 621       6.990000
# 622       6.980000
# 623       6.950000
# 624       6.930000
# 625       6.930000
# 626       6.930000
# 627       6.670000
# 628       6.570000
# 629       6.540000
# 630       6.270000
# 631       6.230000
# 632       6.170000
# 633       5.990000
# 634       5.990000
# 635       5.990000
# 636       5.980000
# 637       5.670000
# 638       5.560000
# 639       5.560000
# 640       5.560000
# 641       5.450000
# 642       5.370000
# 643       5.070000
# 644       5.070000
# 645       4.990000
# 646       4.990000
# 647       4.990000
# 648       4.980000
# 649       4.980000
# 650       4.890000
# 651       4.780000
# 652       4.770000
# 653       4.490000
# 654       4.090000
# 655       4.070000
# 656       3.990000
# 657       3.990000
# 658       3.980000
# 659       3.800000
# 660       3.790000
# 661       3.580000
# 662       3.580000
# 663       3.560000
# 664       3.490000
# 665       3.390000
# 666       3.180000
# 667       3.180000
# 668       3.160000
# 669       2.990000
# 670       2.990000
# 671       2.890000
# 672       2.780000
# 673       2.780000
# 674       2.590000
# 675       2.490000
# 676       2.490000
# 677       2.390000
# 678       2.390000
# 679       2.290000
# 680       2.290000
# 681       2.190000
# 682       2.090000
# 683       1.990000
# 684       1.890000
# 685       1.890000
# 686       1.780000
# 687       1.590000
# 688       1.580000
# 689       1.390000
# 690       1.390000
# 691       0.990000
# 692       0.990000
# 693       0.980000
# 694       0.980000
# 695       0.900000
# 696       0.790000
# 697       0.580000
# 698       0.390000
# 699       0.190000

# %%
all_pairs.head(100)
# Out:
#                                 Item1 Cost Center1  \
# 0                         ENTREE 4.29   Hospital B
# 1                         ENTREE 4.79   Hospital B
# 2                         ENTREE 4.99   Hospital B
# 3                       BURGER CHEESE   Hospital B
# 4                         ENTREE 4.99   Hospital B
# 5                      BACON 3 SLICES   Hospital B
# 6                       SALMON ENTRÉE   Hospital B
# 7                                EGGS   Hospital B
# 8                                EGGS   Hospital B
# 9              ENT -PREMIUM SIDE 1.39   Hospital B
# 10                  ADD A BEVERAGE $1   Hospital A
# 11             ENT -PREMIUM SIDE 1.39   Hospital B
# 12             ENT -PREMIUM SIDE 1.39   Hospital B
# 13                             BURGER   Hospital B
# 14                        ENTREE 4.79   Hospital B
# 15                      BURGER CHEESE   Hospital B
# 16                      BURGER CHEESE   Hospital B
# 17                  ADD A BEVERAGE $1   Hospital A
# 18                  ADD A BEVERAGE $1   Hospital A
# 19                     BACON 3 SLICES   Hospital B
# 20                          SIDE 1.29   Hospital B
# 21                  ADD A BEVERAGE $1   Hospital A
# 22                  ADD A BEVERAGE $1   Hospital A
# 23                         HOME FRIES   Hospital B
# 24                    BISCUIT W/GRAVY   Hospital B
# 25                  ADD A BEVERAGE $1   Hospital A
# 26             ENT -PREMIUM SIDE 1.39   Hospital B
# 27                             BURGER   Hospital B
# 28                      BURGER CHEESE   Hospital B
# 29                            BISCUIT   Hospital B
# 30                  CHICKEN TENDERS 3   Hospital B
# 31                  ADD A BEVERAGE $1   Hospital A
# 32                  ADD A BEVERAGE $1   Hospital A
# 33                            BISCUIT   Hospital B
# 34                  ADD A BEVERAGE $1   Hospital A
# 35                              FRIES   Hospital B
# 36                    BISCUIT W/GRAVY   Hospital B
# 37                     BACON 3 SLICES   Hospital B
# 38  BVC -TOPOCHICO MINERAL WATER-20OZ   Hospital B
# 39                     BREAKFAST TACO   Hospital B
# 40                     BACON 3 SLICES   Hospital B
# 41                    MIX IT UP SALAD   Hospital B
# 42                      SALMON ENTRÉE   Hospital B
# 43                               EGGS   Hospital B
# 44                    MIX IT UP SALAD   Hospital B
# 45                        ENTREE 4.49   Hospital A
# 46                 BAKED SWEET POTATO   Hospital B
# 47                  ADD A BEVERAGE $1   Hospital A
# 48             ENT -PREMIUM SIDE 1.39   Hospital B
# 49                        COFFEE 12OZ   Hospital B
# 50                     BACON 3 SLICES   Hospital B
# 51                     GRILL TOPPINGS   Hospital B
# 52                             BURGER   Hospital B
# 53                         HOME FRIES   Hospital B
# 54                    QUESADILLA MEAT   Hospital B
# 55                        COFFEE 12OZ   Hospital B
# 56                     BREAKFAST TACO   Hospital B
# 57                     BREAKFAST TACO   Hospital B
# 58                         FRUIT CUPS   Hospital A
# 59                 BAKED SWEET POTATO   Hospital B
# 60                        ENTREE 4.29   Hospital B
# 61                              FRIES   Hospital B
# 62  BVC -TOPOCHICO MINERAL WATER-20OZ   Hospital B
# 63                        COFFEE 16OZ   Hospital B
# 64             ENT -PREMIUM SIDE 1.39   Hospital B
# 65                      BURGER CHEESE   Hospital B
# 66                               EGGS   Hospital B
# 67                         FRUIT CUPS   Hospital A
# 68                  ADD A BEVERAGE $1   Hospital A
# 69  BVC -TOPOCHICO MINERAL WATER-20OZ   Hospital B
# 70                  ADD A BEVERAGE $1   Hospital A
# 71  BVC -TOPOCHICO MINERAL WATER-20OZ   Hospital B
# 72                     BACON 3 SLICES   Hospital B
# 73                          SIDE 1.29   Hospital B
# 74  BVC -TOPOCHICO MINERAL WATER-20OZ   Hospital B
# 75                      BACON 1 SLICE   Hospital B
# 76                              FRIES   Hospital B
# 77                  ADD A BEVERAGE $1   Hospital A
# 78                    BISCUIT W/GRAVY   Hospital B
# 79             ENT -PREMIUM SIDE 1.39   Hospital B
# 80                               EGGS   Hospital B
# 81                              FRIES   Hospital B
# 82                     BACON 3 SLICES   Hospital B
# 83                         FRUIT CUPS   Hospital A
# 84                          SIDE 1.29   Hospital B
# 85                  DASANI WATER 20OZ   Hospital B
# 86                    MIX IT UP SALAD   Hospital B
# 87                        ENTREE 4.29   Hospital B
# 88                          SIDE 1.29   Hospital B
# 89                        CARVED-DELI   Hospital B
# 90                            BISCUIT   Hospital B
# 91                  ADD A BEVERAGE $1   Hospital A
# 92                        COFFEE 12OZ   Hospital B
# 93                      BURGER CHEESE   Hospital B
# 94                        ENTREE 4.59   Hospital A
# 95                     BACON 3 SLICES   Hospital B
# 96                        CARVED-DELI   Hospital B
# 97                          SIDE 1.29   Hospital B
# 98                  CHICKEN TENDERS 3   Hospital B
# 99                     GRILLED CHEESE   Hospital B
#
#                                   Item2 Cost Center2  Frequency  Total Revenue
# 0                             SIDE 1.29   Hospital B       3659   21212.819696
# 1                             SIDE 1.29   Hospital B       2171   14391.029803
# 2                             SIDE 1.29   Hospital B        697   11816.789477
# 3                                 FRIES   Hospital B       1017   10889.290032
# 4                             SIDE 1.99   Hospital B        472    8257.439672
# 5                                  EGGS   Hospital B       2348    8250.039975
# 6                             SIDE 1.29   Hospital B        851    7445.399761
# 7                            HOME FRIES   Hospital B       1961    7442.499915
# 8                         SAUSAGE PATTY   Hospital B       1548    7182.989898
# 9                           ENTREE 4.29   Hospital B       1155    6603.079939
# 10                          ENTREE 4.29   Hospital B       1195    6386.999954
# 11                          ENTREE 4.79   Hospital B        972    6249.499947
# 12                            SIDE 1.29   Hospital B       2195    6195.719878
# 13                                FRIES   Hospital B        590    5791.839959
# 14                            SIDE 1.99   Hospital B        785    5452.669977
# 15                       GRILL TOPPINGS   Hospital B        531    5415.299989
# 16                           TATOR TOTS   Hospital A        510    5349.950016
# 17                      CARVED DELI SHL   Hospital A        572    5100.329870
# 18                               BURGER   Hospital B        553    4796.899958
# 19                           HOME FRIES   Hospital B        812    4143.389897
# 20                            SIDE 1.99   Hospital B       1187    4114.239960
# 21                           FRUIT CUPS   Hospital A        438    4094.880009
# 22                      QUESADILLA MEAT   Hospital B        302    3597.999863
# 23                        SAUSAGE PATTY   Hospital B        574    3570.719894
# 24                        SAUSAGE PATTY   Hospital B        452    3435.099962
# 25                       BREAKFAST TACO   Hospital B        729    3390.129964
# 26                          ENTREE 4.99   Hospital B        200    3364.919856
# 27                           TATOR TOTS   Hospital A        347    3288.479977
# 28                          ONION RINGS   Hospital B        298    3214.400010
# 29                        SAUSAGE PATTY   Hospital B        548    3076.739959
# 30                                FRIES   Hospital B        520    3017.719959
# 31                            SIDE 1.29   Hospital B       1197    3016.039948
# 32                        BURGER CHEESE   Hospital B        327    3015.280007
# 33                                 EGGS   Hospital B        890    2973.830050
# 34                CHICKEN TENDER BASKET   Hospital A        576    2961.110088
# 35                      QUESADILLA MEAT   Hospital B        263    2954.609979
# 36                                 EGGS   Hospital B        565    2926.290026
# 37                      BISCUIT W/GRAVY   Hospital B        417    2802.329981
# 38                      MIX IT UP SALAD   Hospital B        266    2717.379930
# 39                          COFFEE 12OZ   Hospital B        357    2700.449971
# 40                        SAUSAGE PATTY   Hospital B        430    2647.429933
# 41  TOPO CHICO TWIST OF GRAPEFRUIT 20OZ   Hospital B        238    2436.359937
# 42                            SIDE 1.99   Hospital B        270    2423.529941
# 43                        REFRIED BEANS   Hospital B        993    2404.010015
# 44        TOPO CHICO TWIST OF LIME 20OZ   Hospital B        234    2380.429938
# 45                            SIDE 1.29   Hospital B        390    2293.519895
# 46                            SIDE 1.29   Hospital B        237    2205.339998
# 47                             TACO BAR   Hospital A         90    2203.359940
# 48                        SALMON ENTRÉE   Hospital B        263    2188.449937
# 49                                 EGGS   Hospital B        442    2173.250003
# 50                              BISCUIT   Hospital B        476    2148.509987
# 51                      QUESADILLA MEAT   Hospital B        214    2117.429996
# 52                          ONION RINGS   Hospital B        226    2117.339985
# 53                        REFRIED BEANS   Hospital B        548    2116.149952
# 54                           TATOR TOTS   Hospital A        183    2071.319977
# 55                           FRUIT CUPS   Hospital A        174    2063.039999
# 56                          COFFEE 16OZ   Hospital B        256    2056.069958
# 57                           FRUIT CUPS   Hospital A        172    1946.909996
# 58                WATER SMARTWATER 20OZ   Hospital B        169    1943.280016
# 59                          ENTREE 4.79   Hospital B        149    1915.740000
# 60                            SIDE 1.99   Hospital B        302    1909.119991
# 61                       GRILLED CHEESE   Hospital B        263    1897.239958
# 62                            SIDE 1.29   Hospital B        470    1859.879959
# 63                                 EGGS   Hospital B        343    1847.849961
# 64                          ENTREE 4.49   Hospital A        308    1847.499925
# 65                   FRIES SWEET POTATO   Hospital B        145    1839.959977
# 66                           FRUIT CUPS   Hospital A        195    1806.020011
# 67                          YOGURT CUPS   Hospital A        132    1798.860005
# 68                    QUESADILLA CHEESE   Hospital B        257    1786.580055
# 69                          ENTREE 4.29   Hospital B        268    1759.729980
# 70                                FRIES   Hospital B        573    1749.220006
# 71                             TACO BAR   Hospital A         63    1656.669954
# 72                        REFRIED BEANS   Hospital B        443    1637.609968
# 73                        SMARTWATER 1L   Hospital B        113    1601.769994
# 74                           FRUIT CUPS   Hospital A        152    1593.029997
# 75                                 EGGS   Hospital B        714    1565.920023
# 76                       GRILL TOPPINGS   Hospital B        420    1533.529986
# 77                           TATOR TOTS   Hospital A        440    1530.349996
# 78                           HOME FRIES   Hospital B        221    1502.039984
# 79                            SIDE 1.99   Hospital B        431    1500.909998
# 80                          HASH BROWNS   Hospital B        392    1490.199983
# 81              SANDWICH CHICKEN BREAST   Hospital B        248    1488.000028
# 82                          COFFEE 12OZ   Hospital B        242    1487.729982
# 83                               OMELET   Hospital B        123    1480.290004
# 84                            SOUP 8 OZ   Hospital B        408    1468.529984
# 85                           FRUIT CUPS   Hospital A        147    1467.320004
# 86                        SMARTWATER 1L   Hospital B         72    1465.029985
# 87  TOPO CHICO TWIST OF GRAPEFRUIT 20OZ   Hospital B        220    1461.339983
# 88  TOPO CHICO TWIST OF GRAPEFRUIT 20OZ   Hospital B        369    1433.409968
# 89  TOPO CHICO TWIST OF GRAPEFRUIT 20OZ   Hospital B        139    1430.229963
# 90                           HOME FRIES   Hospital B        287    1409.999983
# 91                      MIX IT UP SALAD   Hospital B        155    1403.439964
# 92                           HOME FRIES   Hospital B        205    1321.679978
# 93                         GOURMET CAKE   Hospital B        110    1310.730003
# 94                            SIDE 1.29   Hospital B        122    1306.170033
# 95                          COFFEE 16OZ   Hospital B        194    1295.939962
# 96        TOPO CHICO TWIST OF LIME 20OZ   Hospital B        126    1281.309967
# 97        TOPO CHICO TWIST OF LIME 20OZ   Hospital B        325    1280.439972
# 98                           TATOR TOTS   Hospital A        226    1278.969983
# 99                           TATOR TOTS   Hospital A        175    1271.079971
